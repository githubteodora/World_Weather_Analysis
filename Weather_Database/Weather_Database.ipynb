# %%
# Create Latitude and Longitude Combinations
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import gmaps


# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key
from config import g_key

# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# Import the datetime module from the datetime library.
from datetime import datetime

from citipy import citipy

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-60.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-2.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs # When we run this cell, the output is a zip object in memory. The zip object packs each pair of lats and lngs having the same index in their respective array into a tuple.

# %%
# Add the latitudes and longitudes to a list. Here we unzip thw zip from above!
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
print(len(cities))
# Out:
# 872

# %%
# Create an empty list to hold the weather data.
city_data = []

# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
# Out:
# Beginning Data Retrieval
# -----------------------------

# %%
# Loop through all the cities in our list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1 #броим позицията на записа! всеки сет започва от 1, затова при нов сет залагама 1 като начало тук;
    
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+") #когато градът се състои от 2 думи (има празно място м/у думите), кодът ще върне само първата дума. Затова е нужно replace ...

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        # if city_conditions is moved to the bottom of the list - the query returns NaN
        city_conditions = city_weather["weather"][0]["description"] #the [0] is needed; if skipped, the query detects an error and returns no reults
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Conditions": city_conditions})

    # If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass #continue can be used as well!

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Processing Record 1 of Set 1 | sobolevo
# Processing Record 2 of Set 1 | sentyabrskiy
# City not found. Skipping...
# Processing Record 3 of Set 1 | ostrovnoy
# Processing Record 4 of Set 1 | alihe
# Processing Record 5 of Set 1 | kargasok
# Processing Record 6 of Set 1 | richards bay
# Processing Record 7 of Set 1 | kaeo
# Processing Record 8 of Set 1 | saint-philippe
# Processing Record 9 of Set 1 | kamenka
# Processing Record 10 of Set 1 | tura
# Processing Record 11 of Set 1 | dikson
# Processing Record 12 of Set 1 | opuwo
# Processing Record 13 of Set 1 | sorland
# Processing Record 14 of Set 1 | korla
# Processing Record 15 of Set 1 | nalut
# Processing Record 16 of Set 1 | tsihombe
# City not found. Skipping...
# Processing Record 17 of Set 1 | shiyan
# Processing Record 18 of Set 1 | busselton
# Processing Record 19 of Set 1 | okhotsk
# Processing Record 20 of Set 1 | port augusta
# Processing Record 21 of Set 1 | portland
# Processing Record 22 of Set 1 | berlevag
# Processing Record 23 of Set 1 | nacala
# Processing Record 24 of Set 1 | vao
# Processing Record 25 of Set 1 | mount gambier
# Processing Record 26 of Set 1 | vanimo
# Processing Record 27 of Set 1 | nogliki
# Processing Record 28 of Set 1 | domoni
# Processing Record 29 of Set 1 | buraydah
# Processing Record 30 of Set 1 | ulladulla
# Processing Record 31 of Set 1 | doha
# Processing Record 32 of Set 1 | zhaotong
# Processing Record 33 of Set 1 | salalah
# Processing Record 34 of Set 1 | nyrob
# Processing Record 35 of Set 1 | palana
# Processing Record 36 of Set 1 | cap malheureux
# Processing Record 37 of Set 1 | severo-kurilsk
# Processing Record 38 of Set 1 | chake chake
# Processing Record 39 of Set 1 | nikolskoye
# Processing Record 40 of Set 1 | namibe
# Processing Record 41 of Set 1 | ahipara
# Processing Record 42 of Set 1 | hobart
# Processing Record 43 of Set 1 | yongan
# Processing Record 44 of Set 1 | mahebourg
# Processing Record 45 of Set 1 | carnarvon
# Processing Record 46 of Set 1 | abha
# Processing Record 47 of Set 1 | cape town
# Processing Record 48 of Set 1 | asau
# Processing Record 49 of Set 1 | banjarmasin
# Processing Record 50 of Set 1 | hithadhoo
# Processing Record 1 of Set 2 | airai
# Processing Record 2 of Set 2 | padang
# Processing Record 3 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 4 of Set 2 | mount isa
# Processing Record 5 of Set 2 | ondorhaan
# City not found. Skipping...
# Processing Record 6 of Set 2 | umzimvubu
# City not found. Skipping...
# Processing Record 7 of Set 2 | matara
# Processing Record 8 of Set 2 | maujao
# City not found. Skipping...
# Processing Record 9 of Set 2 | isangel
# Processing Record 10 of Set 2 | sagaing
# Processing Record 11 of Set 2 | oum hadjer
# Processing Record 12 of Set 2 | ashiya
# Processing Record 13 of Set 2 | yulara
# Processing Record 14 of Set 2 | kavieng
# Processing Record 15 of Set 2 | victoria
# Processing Record 16 of Set 2 | naftah
# City not found. Skipping...
# Processing Record 17 of Set 2 | makubetsu
# Processing Record 18 of Set 2 | zarya
# Processing Record 19 of Set 2 | cherskiy
# Processing Record 20 of Set 2 | lasa
# Processing Record 21 of Set 2 | majene
# Processing Record 22 of Set 2 | khatanga
# Processing Record 23 of Set 2 | banjar
# Processing Record 24 of Set 2 | port blair
# Processing Record 25 of Set 2 | nishihara
# Processing Record 26 of Set 2 | diosti
# Processing Record 27 of Set 2 | karamea
# City not found. Skipping...
# Processing Record 28 of Set 2 | mehran
# Processing Record 29 of Set 2 | tanshui
# City not found. Skipping...
# Processing Record 30 of Set 2 | tuatapere
# Processing Record 31 of Set 2 | butaritari
# Processing Record 32 of Set 2 | grand river south east
# City not found. Skipping...
# Processing Record 33 of Set 2 | alotau
# City not found. Skipping...
# Processing Record 34 of Set 2 | esperance
# Processing Record 35 of Set 2 | afzalpur
# Processing Record 36 of Set 2 | leningradskiy
# Processing Record 37 of Set 2 | talnakh
# Processing Record 38 of Set 2 | aitape
# Processing Record 39 of Set 2 | sindand
# City not found. Skipping...
# Processing Record 40 of Set 2 | randvere
# City not found. Skipping...
# Processing Record 41 of Set 2 | arlit
# Processing Record 42 of Set 2 | tera
# Processing Record 43 of Set 2 | albany
# Processing Record 44 of Set 2 | beloha
# Processing Record 45 of Set 2 | bluff
# Processing Record 46 of Set 2 | teluk nibung
# Processing Record 47 of Set 2 | faya
# Processing Record 48 of Set 2 | grand gaube
# Processing Record 49 of Set 2 | datong
# Processing Record 50 of Set 2 | baruun-urt
# Processing Record 1 of Set 3 | longyearbyen
# Processing Record 2 of Set 3 | yar-sale
# Processing Record 3 of Set 3 | ksenyevka
# City not found. Skipping...
# Processing Record 4 of Set 3 | geraldton
# Processing Record 5 of Set 3 | tiksi
# Processing Record 6 of Set 3 | bandarbeyla
# Processing Record 7 of Set 3 | yinchuan
# Processing Record 8 of Set 3 | adrar
# Processing Record 9 of Set 3 | smila
# Processing Record 10 of Set 3 | dosso
# Processing Record 11 of Set 3 | krasnogorsk
# Processing Record 12 of Set 3 | kruisfontein
# Processing Record 13 of Set 3 | hobyo
# Processing Record 14 of Set 3 | pishin
# Processing Record 15 of Set 3 | palabuhanratu
# City not found. Skipping...
# Processing Record 16 of Set 3 | yunjinghong
# City not found. Skipping...
# Processing Record 17 of Set 3 | bilari
# Processing Record 18 of Set 3 | den helder
# Processing Record 19 of Set 3 | te anau
# Processing Record 20 of Set 3 | sur
# Processing Record 21 of Set 3 | new norfolk
# Processing Record 22 of Set 3 | bjornevatn
# Processing Record 23 of Set 3 | vardo
# Processing Record 24 of Set 3 | amderma
# City not found. Skipping...
# Processing Record 25 of Set 3 | zaliztsi
# Processing Record 26 of Set 3 | belushya guba
# City not found. Skipping...
# Processing Record 27 of Set 3 | hambantota
# Processing Record 28 of Set 3 | ngukurr
# City not found. Skipping...
# Processing Record 29 of Set 3 | gat
# Processing Record 30 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 31 of Set 3 | yatou
# Processing Record 32 of Set 3 | hotaka
# Processing Record 33 of Set 3 | suhbaatar
# Processing Record 34 of Set 3 | luwingu
# Processing Record 35 of Set 3 | luderitz
# Processing Record 36 of Set 3 | christchurch
# Processing Record 37 of Set 3 | nyurba
# Processing Record 38 of Set 3 | skjervoy
# Processing Record 39 of Set 3 | naze
# Processing Record 40 of Set 3 | wanning
# Processing Record 41 of Set 3 | port hedland
# Processing Record 42 of Set 3 | jumla
# Processing Record 43 of Set 3 | chik
# Processing Record 44 of Set 3 | bela
# Processing Record 45 of Set 3 | hokitika
# Processing Record 46 of Set 3 | movila
# Processing Record 47 of Set 3 | bundaberg
# Processing Record 48 of Set 3 | fukue
# Processing Record 49 of Set 3 | pyaozerskiy
# Processing Record 50 of Set 3 | hunza
# City not found. Skipping...
# Processing Record 1 of Set 4 | nizhneyansk
# City not found. Skipping...
# Processing Record 2 of Set 4 | kaitangata
# Processing Record 3 of Set 4 | wenling
# Processing Record 4 of Set 4 | hami
# Processing Record 5 of Set 4 | hermanus
# Processing Record 6 of Set 4 | chirongui
# Processing Record 7 of Set 4 | poum
# Processing Record 8 of Set 4 | koumac
# Processing Record 9 of Set 4 | port keats
# Processing Record 10 of Set 4 | lorengau
# Processing Record 11 of Set 4 | mirnyy
# Processing Record 12 of Set 4 | swan hill
# Processing Record 13 of Set 4 | liminangcong
# City not found. Skipping...
# Processing Record 14 of Set 4 | morondava
# Processing Record 15 of Set 4 | bambous virieux
# Processing Record 16 of Set 4 | tsiroanomandidy
# Processing Record 17 of Set 4 | thyboron
# Processing Record 18 of Set 4 | tevriz
# Processing Record 19 of Set 4 | maria aurora
# Processing Record 20 of Set 4 | honiara
# Processing Record 21 of Set 4 | gushikawa
# Processing Record 22 of Set 4 | vangaindrano
# Processing Record 23 of Set 4 | dzaoudzi
# Processing Record 24 of Set 4 | brae
# Processing Record 25 of Set 4 | quatre cocos
# Processing Record 26 of Set 4 | iisaku
# Processing Record 27 of Set 4 | port lincoln
# Processing Record 28 of Set 4 | noyabrsk
# Processing Record 29 of Set 4 | nabire
# Processing Record 30 of Set 4 | saint-leu
# Processing Record 31 of Set 4 | atambua
# Processing Record 32 of Set 4 | lolua
# City not found. Skipping...
# Processing Record 33 of Set 4 | borazjan
# Processing Record 34 of Set 4 | pevek
# Processing Record 35 of Set 4 | griffith
# Processing Record 36 of Set 4 | gamba
# Processing Record 37 of Set 4 | lahat
# Processing Record 38 of Set 4 | sergeyevka
# Processing Record 39 of Set 4 | muli
# Processing Record 40 of Set 4 | si bun ruang
# Processing Record 41 of Set 4 | klaksvik
# Processing Record 42 of Set 4 | rawannawi
# City not found. Skipping...
# Processing Record 43 of Set 4 | auki
# Processing Record 44 of Set 4 | bengkulu
# Processing Record 45 of Set 4 | mahenge
# Processing Record 46 of Set 4 | teya
# Processing Record 47 of Set 4 | atka
# City not found. Skipping...
# Processing Record 48 of Set 4 | vung tau
# Processing Record 49 of Set 4 | kununurra
# Processing Record 50 of Set 4 | samarai
# Processing Record 1 of Set 5 | murygino
# Processing Record 2 of Set 5 | gizo
# Processing Record 3 of Set 5 | manado
# Processing Record 4 of Set 5 | honningsvag
# Processing Record 5 of Set 5 | dunda
# Processing Record 6 of Set 5 | zhangjiakou
# Processing Record 7 of Set 5 | jiroft
# City not found. Skipping...
# Processing Record 8 of Set 5 | jega
# Processing Record 9 of Set 5 | east london
# Processing Record 10 of Set 5 | salzkotten
# Processing Record 11 of Set 5 | ormara
# Processing Record 12 of Set 5 | flinders
# Processing Record 13 of Set 5 | balkhash
# Processing Record 14 of Set 5 | tete
# Processing Record 15 of Set 5 | barzas
# Processing Record 16 of Set 5 | kanniyakumari
# Processing Record 17 of Set 5 | nsukka
# Processing Record 18 of Set 5 | pitea
# Processing Record 19 of Set 5 | kalmunai
# Processing Record 20 of Set 5 | hervey bay
# Processing Record 21 of Set 5 | nakamura
# Processing Record 22 of Set 5 | tonj
# Processing Record 23 of Set 5 | srandakan
# Processing Record 24 of Set 5 | marzuq
# Processing Record 25 of Set 5 | gladstone
# Processing Record 26 of Set 5 | karratha
# Processing Record 27 of Set 5 | lahore
# Processing Record 28 of Set 5 | kemin
# Processing Record 29 of Set 5 | cairns
# Processing Record 30 of Set 5 | phonhong
# Processing Record 31 of Set 5 | taybad
# Processing Record 32 of Set 5 | pontianak
# Processing Record 33 of Set 5 | odweyne
# Processing Record 34 of Set 5 | konstantinovka
# Processing Record 35 of Set 5 | solovetskiy
# City not found. Skipping...
# Processing Record 36 of Set 5 | svetlaya
# Processing Record 37 of Set 5 | yekaterinovka
# Processing Record 38 of Set 5 | rockhampton
# Processing Record 39 of Set 5 | skalistyy
# City not found. Skipping...
# Processing Record 40 of Set 5 | luena
# Processing Record 41 of Set 5 | mareeba
# Processing Record 42 of Set 5 | strelka
# Processing Record 43 of Set 5 | xining
# Processing Record 44 of Set 5 | zhanaozen
# Processing Record 45 of Set 5 | kota kinabalu
# Processing Record 46 of Set 5 | payo
# Processing Record 47 of Set 5 | manono
# Processing Record 48 of Set 5 | saint-paul
# Processing Record 49 of Set 5 | sala
# Processing Record 50 of Set 5 | kudahuvadhoo
# Processing Record 1 of Set 6 | zhob
# Processing Record 2 of Set 6 | vanavara
# Processing Record 3 of Set 6 | perevolotskiy
# Processing Record 4 of Set 6 | raudeberg
# Processing Record 5 of Set 6 | saskylakh
# Processing Record 6 of Set 6 | mehamn
# Processing Record 7 of Set 6 | zhigansk
# Processing Record 8 of Set 6 | daru
# Processing Record 9 of Set 6 | yumen
# Processing Record 10 of Set 6 | awjilah
# Processing Record 11 of Set 6 | samarinda
# Processing Record 12 of Set 6 | port alfred
# Processing Record 13 of Set 6 | broken hill
# Processing Record 14 of Set 6 | kidal
# Processing Record 15 of Set 6 | ossora
# Processing Record 16 of Set 6 | nola
# Processing Record 17 of Set 6 | makasar
# Processing Record 18 of Set 6 | khandyga
# Processing Record 19 of Set 6 | dudinka
# Processing Record 20 of Set 6 | mahibadhoo
# Processing Record 21 of Set 6 | labutta
# City not found. Skipping...
# Processing Record 22 of Set 6 | ambon
# Processing Record 23 of Set 6 | katsuura
# Processing Record 24 of Set 6 | pizhanka
# Processing Record 25 of Set 6 | guna
# Processing Record 26 of Set 6 | karkaralinsk
# City not found. Skipping...
# Processing Record 27 of Set 6 | aksarka
# Processing Record 28 of Set 6 | port elizabeth
# Processing Record 29 of Set 6 | kainantu
# Processing Record 30 of Set 6 | riyadh
# Processing Record 31 of Set 6 | bereda
# Processing Record 32 of Set 6 | eyl
# Processing Record 33 of Set 6 | novosokolniki
# Processing Record 34 of Set 6 | swellendam
# Processing Record 35 of Set 6 | siare
# City not found. Skipping...
# Processing Record 36 of Set 6 | serenje
# Processing Record 37 of Set 6 | uruzgan
# Processing Record 38 of Set 6 | alyangula
# Processing Record 39 of Set 6 | rangoon
# Processing Record 40 of Set 6 | erzin
# Processing Record 41 of Set 6 | baringo
# Processing Record 42 of Set 6 | ruatoria
# City not found. Skipping...
# Processing Record 43 of Set 6 | masuguru
# Processing Record 44 of Set 6 | gumushane
# City not found. Skipping...
# Processing Record 45 of Set 6 | bosaso
# Processing Record 46 of Set 6 | binzhou
# Processing Record 47 of Set 6 | oranjemund
# Processing Record 48 of Set 6 | jagdalpur
# Processing Record 49 of Set 6 | pagondas
# City not found. Skipping...
# Processing Record 50 of Set 6 | narsingi
# Processing Record 1 of Set 7 | churapcha
# Processing Record 2 of Set 7 | strezhevoy
# Processing Record 3 of Set 7 | port moresby
# Processing Record 4 of Set 7 | vintila voda
# Processing Record 5 of Set 7 | ust-kulom
# Processing Record 6 of Set 7 | xichang
# Processing Record 7 of Set 7 | sambava
# Processing Record 8 of Set 7 | noumea
# Processing Record 9 of Set 7 | ingham
# Processing Record 10 of Set 7 | bahce
# Processing Record 11 of Set 7 | otjimbingwe
# Processing Record 12 of Set 7 | asyut
# Processing Record 13 of Set 7 | ust-koksa
# Processing Record 14 of Set 7 | tahe
# Processing Record 15 of Set 7 | dubbo
# Processing Record 16 of Set 7 | pietermaritzburg
# Processing Record 17 of Set 7 | shchelyayur
# City not found. Skipping...
# Processing Record 18 of Set 7 | ayagoz
# Processing Record 19 of Set 7 | ambilobe
# Processing Record 20 of Set 7 | sinjai
# Processing Record 21 of Set 7 | dinsor
# City not found. Skipping...
# Processing Record 22 of Set 7 | queenstown
# Processing Record 23 of Set 7 | galgani
# City not found. Skipping...
# Processing Record 24 of Set 7 | broome
# Processing Record 25 of Set 7 | margate
# Processing Record 26 of Set 7 | mocuba
# Processing Record 27 of Set 7 | hohhot
# Processing Record 28 of Set 7 | simpang
# Processing Record 29 of Set 7 | kedrovyy
# Processing Record 30 of Set 7 | xuddur
# Processing Record 31 of Set 7 | kachikau
# City not found. Skipping...
# Processing Record 32 of Set 7 | malabo
# Processing Record 33 of Set 7 | srednekolymsk
# Processing Record 34 of Set 7 | tobol
# Processing Record 35 of Set 7 | bairiki
# Processing Record 36 of Set 7 | bitlis
# Processing Record 37 of Set 7 | hirtshals
# Processing Record 38 of Set 7 | robat karim
# Processing Record 39 of Set 7 | luanda
# Processing Record 40 of Set 7 | saint-joseph
# Processing Record 41 of Set 7 | vidim
# Processing Record 42 of Set 7 | tumannyy
# City not found. Skipping...
# Processing Record 43 of Set 7 | taksimo
# Processing Record 44 of Set 7 | parbatipur
# Processing Record 45 of Set 7 | biloela
# Processing Record 46 of Set 7 | kovernino
# Processing Record 47 of Set 7 | nurota
# Processing Record 48 of Set 7 | la maddalena
# Processing Record 49 of Set 7 | svetlogorsk
# Processing Record 50 of Set 7 | yining
# Processing Record 1 of Set 8 | uddevalla
# Processing Record 2 of Set 8 | hovd
# Processing Record 3 of Set 8 | vyara
# Processing Record 4 of Set 8 | dauriya
# Processing Record 5 of Set 8 | bam
# Processing Record 6 of Set 8 | bredasdorp
# Processing Record 7 of Set 8 | bontang
# Processing Record 8 of Set 8 | janow lubelski
# Processing Record 9 of Set 8 | buala
# Processing Record 10 of Set 8 | zheleznodorozhnyy
# Processing Record 11 of Set 8 | karaul
# City not found. Skipping...
# Processing Record 12 of Set 8 | esso
# Processing Record 13 of Set 8 | dalupirip
# Processing Record 14 of Set 8 | roma
# Processing Record 15 of Set 8 | isiro
# Processing Record 16 of Set 8 | bridlington
# Processing Record 17 of Set 8 | mtwara
# Processing Record 18 of Set 8 | dmitriyevka
# Processing Record 19 of Set 8 | kokoshkino
# Processing Record 20 of Set 8 | camacupa
# Processing Record 21 of Set 8 | chynadiyovo
# Processing Record 22 of Set 8 | fukuma
# Processing Record 23 of Set 8 | bargal
# City not found. Skipping...
# Processing Record 24 of Set 8 | mezen
# Processing Record 25 of Set 8 | sinkat
# City not found. Skipping...
# Processing Record 26 of Set 8 | talah
# City not found. Skipping...
# Processing Record 27 of Set 8 | aban
# Processing Record 28 of Set 8 | misratah
# Processing Record 29 of Set 8 | taldan
# Processing Record 30 of Set 8 | yeletskiy
# City not found. Skipping...
# Processing Record 31 of Set 8 | aykhal
# Processing Record 32 of Set 8 | zverinogolovskoye
# Processing Record 33 of Set 8 | kristiinankaupunki
# Processing Record 34 of Set 8 | beringovskiy
# Processing Record 35 of Set 8 | souillac
# Processing Record 36 of Set 8 | katangli
# Processing Record 37 of Set 8 | ijaki
# City not found. Skipping...
# Processing Record 38 of Set 8 | chamba
# Processing Record 39 of Set 8 | ellisras
# Processing Record 40 of Set 8 | southbridge
# Processing Record 41 of Set 8 | betong
# Processing Record 42 of Set 8 | rampura
# Processing Record 43 of Set 8 | ondjiva
# Processing Record 44 of Set 8 | seoul
# Processing Record 45 of Set 8 | batagay
# Processing Record 46 of Set 8 | biograd na moru
# Processing Record 47 of Set 8 | mocambique
# City not found. Skipping...
# Processing Record 48 of Set 8 | kirakira
# Processing Record 49 of Set 8 | maarianhamina
# Processing Record 50 of Set 8 | keuruu
# Processing Record 1 of Set 9 | neustrelitz
# Processing Record 2 of Set 9 | toora-khem
# Processing Record 3 of Set 9 | komsomolskiy
# Processing Record 4 of Set 9 | imeni poliny osipenko
# Processing Record 5 of Set 9 | palaikastron
# Processing Record 6 of Set 9 | belyy yar
# Processing Record 7 of Set 9 | lubao
# Processing Record 8 of Set 9 | alice springs
# Processing Record 9 of Set 9 | yian
# City not found. Skipping...
# Processing Record 10 of Set 9 | dzhusaly
# City not found. Skipping...
# Processing Record 11 of Set 9 | krasnovishersk
# Processing Record 12 of Set 9 | moshkovo
# Processing Record 13 of Set 9 | changtu
# Processing Record 14 of Set 9 | tabialan
# City not found. Skipping...
# Processing Record 15 of Set 9 | skelleftea
# Processing Record 16 of Set 9 | kathmandu
# Processing Record 17 of Set 9 | costinesti
# Processing Record 18 of Set 9 | voi
# Processing Record 19 of Set 9 | hirara
# Processing Record 20 of Set 9 | tuban
# Processing Record 21 of Set 9 | bosobolo
# Processing Record 22 of Set 9 | nemuro
# Processing Record 23 of Set 9 | surgut
# Processing Record 24 of Set 9 | metu
# Processing Record 25 of Set 9 | tiruvottiyur
# City not found. Skipping...
# Processing Record 26 of Set 9 | atherton
# Processing Record 27 of Set 9 | andevoranto
# City not found. Skipping...
# Processing Record 28 of Set 9 | mangochi
# Processing Record 29 of Set 9 | yuanping
# Processing Record 30 of Set 9 | ararat
# Processing Record 31 of Set 9 | dukat
# Processing Record 32 of Set 9 | sjenica
# Processing Record 33 of Set 9 | sistranda
# Processing Record 34 of Set 9 | haibowan
# City not found. Skipping...
# Processing Record 35 of Set 9 | maralal
# Processing Record 36 of Set 9 | malakal
# Processing Record 37 of Set 9 | konakovo
# Processing Record 38 of Set 9 | kampene
# Processing Record 39 of Set 9 | dargaville
# Processing Record 40 of Set 9 | berestechko
# Processing Record 41 of Set 9 | kysyl-syr
# Processing Record 42 of Set 9 | yuci
# Processing Record 43 of Set 9 | rong kwang
# Processing Record 44 of Set 9 | huilong
# Processing Record 45 of Set 9 | semey
# Processing Record 46 of Set 9 | nur
# Processing Record 47 of Set 9 | bolshegrivskoye
# City not found. Skipping...
# Processing Record 48 of Set 9 | ust-barguzin
# Processing Record 49 of Set 9 | labuhan
# Processing Record 50 of Set 9 | abu jubayhah
# City not found. Skipping...
# Processing Record 1 of Set 10 | gusinoye ozero
# Processing Record 2 of Set 10 | onega
# Processing Record 3 of Set 10 | navabad
# City not found. Skipping...
# Processing Record 4 of Set 10 | chamrajnagar
# Processing Record 5 of Set 10 | kjopsvik
# Processing Record 6 of Set 10 | alekseyevsk
# Processing Record 7 of Set 10 | orhei
# Processing Record 8 of Set 10 | nova odesa
# Processing Record 9 of Set 10 | alekseyevka
# Processing Record 10 of Set 10 | chengkung
# City not found. Skipping...
# Processing Record 11 of Set 10 | sarangani
# Processing Record 12 of Set 10 | saldanha
# Processing Record 13 of Set 10 | jamestown
# Processing Record 14 of Set 10 | wronki
# Processing Record 15 of Set 10 | hasaki
# Processing Record 16 of Set 10 | kovdor
# Processing Record 17 of Set 10 | belaya gora
# Processing Record 18 of Set 10 | dunedin
# Processing Record 19 of Set 10 | zeya
# Processing Record 20 of Set 10 | altay
# Processing Record 21 of Set 10 | antibes
# Processing Record 22 of Set 10 | kyzyl-suu
# Processing Record 23 of Set 10 | meulaboh
# Processing Record 24 of Set 10 | taman
# Processing Record 25 of Set 10 | abalak
# Processing Record 26 of Set 10 | yudong
# Processing Record 27 of Set 10 | linqiong
# Processing Record 28 of Set 10 | port-gentil
# Processing Record 29 of Set 10 | shache
# Processing Record 30 of Set 10 | gigmoto
# Processing Record 31 of Set 10 | warrnambool
# Processing Record 32 of Set 10 | rungata
# City not found. Skipping...
# Processing Record 33 of Set 10 | sosva
# Processing Record 34 of Set 10 | sola
# Processing Record 35 of Set 10 | nyagan
# Processing Record 36 of Set 10 | bratsk
# Processing Record 37 of Set 10 | utiroa
# City not found. Skipping...
# Processing Record 38 of Set 10 | tazovskiy
# Processing Record 39 of Set 10 | chipinge
# Processing Record 40 of Set 10 | masty
# Processing Record 41 of Set 10 | baykit
# Processing Record 42 of Set 10 | kodinar
# Processing Record 43 of Set 10 | ystad
# Processing Record 44 of Set 10 | ust-tsilma
# Processing Record 45 of Set 10 | bardiyah
# Processing Record 46 of Set 10 | kamenskoye
# City not found. Skipping...
# Processing Record 47 of Set 10 | deputatskiy
# Processing Record 48 of Set 10 | lokhvytsya
# Processing Record 49 of Set 10 | northam
# Processing Record 50 of Set 10 | tezu
# Processing Record 1 of Set 11 | aswan
# Processing Record 2 of Set 11 | pangody
# Processing Record 3 of Set 11 | takhtamygda
# Processing Record 4 of Set 11 | harlingen
# Processing Record 5 of Set 11 | helsinki
# Processing Record 6 of Set 11 | gao
# Processing Record 7 of Set 11 | tshikapa
# Processing Record 8 of Set 11 | luba
# Processing Record 9 of Set 11 | beidao
# Processing Record 10 of Set 11 | toliary
# City not found. Skipping...
# Processing Record 11 of Set 11 | bakchar
# Processing Record 12 of Set 11 | carquefou
# Processing Record 13 of Set 11 | amga
# Processing Record 14 of Set 11 | redhakhol
# City not found. Skipping...
# Processing Record 15 of Set 11 | sakakah
# Processing Record 16 of Set 11 | kuah
# Processing Record 17 of Set 11 | cigand
# Processing Record 18 of Set 11 | minna
# Processing Record 19 of Set 11 | novoagansk
# Processing Record 20 of Set 11 | mmabatho
# Processing Record 21 of Set 11 | varnamo
# Processing Record 22 of Set 11 | beyneu
# Processing Record 23 of Set 11 | mogadishu
# Processing Record 24 of Set 11 | duz
# City not found. Skipping...
# Processing Record 25 of Set 11 | kuche
# City not found. Skipping...
# Processing Record 26 of Set 11 | chokurdakh
# Processing Record 27 of Set 11 | follebu
# Processing Record 28 of Set 11 | boatlaname
# City not found. Skipping...
# Processing Record 29 of Set 11 | shingu
# Processing Record 30 of Set 11 | tambura
# Processing Record 31 of Set 11 | karacabey
# Processing Record 32 of Set 11 | thanh hoa
# Processing Record 33 of Set 11 | lafia
# Processing Record 34 of Set 11 | bilma
# Processing Record 35 of Set 11 | ziro
# Processing Record 36 of Set 11 | chaoyang
# Processing Record 37 of Set 11 | chiredzi
# Processing Record 38 of Set 11 | ak-dovurak
# Processing Record 39 of Set 11 | helong
# Processing Record 40 of Set 11 | suoyarvi
# Processing Record 41 of Set 11 | mumford
# Processing Record 42 of Set 11 | kyzyl
# Processing Record 43 of Set 11 | vestbygda
# City not found. Skipping...
# Processing Record 44 of Set 11 | magole
# Processing Record 45 of Set 11 | ushtobe
# Processing Record 46 of Set 11 | najran
# Processing Record 47 of Set 11 | murgab
# Processing Record 48 of Set 11 | tuensang
# Processing Record 49 of Set 11 | smidovich
# Processing Record 50 of Set 11 | loding
# Processing Record 1 of Set 12 | fatehpur
# Processing Record 2 of Set 12 | nguiu
# City not found. Skipping...
# Processing Record 3 of Set 12 | marsa matruh
# Processing Record 4 of Set 12 | tual
# Processing Record 5 of Set 12 | urusha
# Processing Record 6 of Set 12 | kwinana
# Processing Record 7 of Set 12 | rayevskiy
# Processing Record 8 of Set 12 | goryachegorsk
# Processing Record 9 of Set 12 | angoche
# Processing Record 10 of Set 12 | denpasar
# Processing Record 11 of Set 12 | omboue
# Processing Record 12 of Set 12 | karonga
# Processing Record 13 of Set 12 | sipoo
# Processing Record 14 of Set 12 | bur gabo
# City not found. Skipping...
# Processing Record 15 of Set 12 | ayan
# Processing Record 16 of Set 12 | khonuu
# City not found. Skipping...
# Processing Record 17 of Set 12 | darhan
# Processing Record 18 of Set 12 | umba
# Processing Record 19 of Set 12 | maine-soroa
# Processing Record 20 of Set 12 | wuda
# Processing Record 21 of Set 12 | canakkale
# Processing Record 22 of Set 12 | tabora
# Processing Record 23 of Set 12 | babanusah
# City not found. Skipping...
# Processing Record 24 of Set 12 | vikindu
# Processing Record 25 of Set 12 | stoyba
# City not found. Skipping...
# Processing Record 26 of Set 12 | shetpe
# Processing Record 27 of Set 12 | warri
# Processing Record 28 of Set 12 | pamekasan
# Processing Record 29 of Set 12 | kavaratti
# Processing Record 30 of Set 12 | dubai
# Processing Record 31 of Set 12 | sarkand
# Processing Record 32 of Set 12 | martapura
# Processing Record 33 of Set 12 | hulan ergi
# Processing Record 34 of Set 12 | jiuquan
# Processing Record 35 of Set 12 | fenoarivo
# Processing Record 36 of Set 12 | lingao
# Processing Record 37 of Set 12 | zilupe
# Processing Record 38 of Set 12 | eslov
# Processing Record 39 of Set 12 | mansehra
# Processing Record 40 of Set 12 | inta
# Processing Record 41 of Set 12 | roald
# Processing Record 42 of Set 12 | okakarara
# Processing Record 43 of Set 12 | lashio
# Processing Record 44 of Set 12 | kodinsk
# Processing Record 45 of Set 12 | chernyshevskiy
# Processing Record 46 of Set 12 | san vicente
# Processing Record 47 of Set 12 | teguldet
# Processing Record 48 of Set 12 | ludvika
# Processing Record 49 of Set 12 | akim swedru
# Processing Record 50 of Set 12 | kiunga
# Processing Record 1 of Set 13 | norrtalje
# Processing Record 2 of Set 13 | kendari
# Processing Record 3 of Set 13 | katsiveli
# City not found. Skipping...
# Processing Record 4 of Set 13 | qandahar
# City not found. Skipping...
# Processing Record 5 of Set 13 | gayny
# Processing Record 6 of Set 13 | tokmak
# Processing Record 7 of Set 13 | balezino
# Processing Record 8 of Set 13 | abu dhabi
# Processing Record 9 of Set 13 | mnogovershinnyy
# Processing Record 10 of Set 13 | makat
# Processing Record 11 of Set 13 | lovozero
# Processing Record 12 of Set 13 | okha
# Processing Record 13 of Set 13 | kentau
# Processing Record 14 of Set 13 | nhulunbuy
# Processing Record 15 of Set 13 | muzhi
# Processing Record 16 of Set 13 | usolye-sibirskoye
# Processing Record 17 of Set 13 | gravdal
# Processing Record 18 of Set 13 | waingapu
# Processing Record 19 of Set 13 | kurchum
# Processing Record 20 of Set 13 | tagusao
# Processing Record 21 of Set 13 | toamasina
# Processing Record 22 of Set 13 | namatanai
# Processing Record 23 of Set 13 | letpadan
# Processing Record 24 of Set 13 | sudova vyshnya
# Processing Record 25 of Set 13 | yerbogachen
# Processing Record 26 of Set 13 | jalu
# Processing Record 27 of Set 13 | jiwani
# Processing Record 28 of Set 13 | karasburg
# Processing Record 29 of Set 13 | delmas
# Processing Record 30 of Set 13 | urumqi
# Processing Record 31 of Set 13 | bojnurd
# Processing Record 32 of Set 13 | buin
# Processing Record 33 of Set 13 | benguela
# Processing Record 34 of Set 13 | bumba
# Processing Record 35 of Set 13 | sayhat
# Processing Record 36 of Set 13 | mukhen
# Processing Record 37 of Set 13 | galiwinku
# City not found. Skipping...
# Processing Record 38 of Set 13 | gayeri
# Processing Record 39 of Set 13 | kitob
# Processing Record 40 of Set 13 | seymchan
# Processing Record 41 of Set 13 | meyungs
# City not found. Skipping...
# Processing Record 42 of Set 13 | narrabri
# Processing Record 43 of Set 13 | talawdi
# City not found. Skipping...
# Processing Record 44 of Set 13 | seydi
# Processing Record 45 of Set 13 | sorong
# Processing Record 46 of Set 13 | vitim
# Processing Record 47 of Set 13 | yashkul
# Processing Record 48 of Set 13 | mandalgovi
# Processing Record 49 of Set 13 | kuroiso
# Processing Record 50 of Set 13 | megion
# Processing Record 1 of Set 14 | gumdag
# Processing Record 2 of Set 14 | alugan
# Processing Record 3 of Set 14 | russell
# Processing Record 4 of Set 14 | birao
# Processing Record 5 of Set 14 | hirado
# Processing Record 6 of Set 14 | sogne
# Processing Record 7 of Set 14 | banyuwangi
# Processing Record 8 of Set 14 | hastings
# Processing Record 9 of Set 14 | torbat-e jam
# Processing Record 10 of Set 14 | mudgee
# Processing Record 11 of Set 14 | abnub
# Processing Record 12 of Set 14 | bijie
# Processing Record 13 of Set 14 | yeppoon
# Processing Record 14 of Set 14 | mkokotoni
# Processing Record 15 of Set 14 | uige
# Processing Record 16 of Set 14 | kyshtovka
# Processing Record 17 of Set 14 | kalga
# Processing Record 18 of Set 14 | mikhaylovka
# Processing Record 19 of Set 14 | tveit
# Processing Record 20 of Set 14 | balad
# Processing Record 21 of Set 14 | machilipatnam
# Processing Record 22 of Set 14 | ishigaki
# Processing Record 23 of Set 14 | kashan
# Processing Record 24 of Set 14 | bacuit
# City not found. Skipping...
# Processing Record 25 of Set 14 | songjianghe
# Processing Record 26 of Set 14 | colac
# Processing Record 27 of Set 14 | horsham
# Processing Record 28 of Set 14 | laizhou
# Processing Record 29 of Set 14 | springbok
# Processing Record 30 of Set 14 | phalombe
# Processing Record 31 of Set 14 | bowen
# Processing Record 32 of Set 14 | orthez
# Processing Record 33 of Set 14 | sorrento
# Processing Record 34 of Set 14 | mujiayingzi
# Processing Record 35 of Set 14 | juegang
# Processing Record 36 of Set 14 | yenagoa
# Processing Record 37 of Set 14 | taywarah
# Processing Record 38 of Set 14 | howard springs
# Processing Record 39 of Set 14 | grabovo
# Processing Record 40 of Set 14 | lodja
# Processing Record 41 of Set 14 | baishishan
# Processing Record 42 of Set 14 | ust-bolsheretsk
# City not found. Skipping...
# Processing Record 43 of Set 14 | sarakhs
# Processing Record 44 of Set 14 | maun
# Processing Record 45 of Set 14 | leshan
# Processing Record 46 of Set 14 | jizan
# Processing Record 47 of Set 14 | tornio
# Processing Record 48 of Set 14 | thinadhoo
# Processing Record 49 of Set 14 | siocon
# Processing Record 50 of Set 14 | moussoro
# Processing Record 1 of Set 15 | namie
# Processing Record 2 of Set 15 | ankazoabo
# Processing Record 3 of Set 15 | eldikan
# City not found. Skipping...
# Processing Record 4 of Set 15 | coolum beach
# Processing Record 5 of Set 15 | palaiokhora
# City not found. Skipping...
# Processing Record 6 of Set 15 | kieta
# Processing Record 7 of Set 15 | chardara
# Processing Record 8 of Set 15 | batemans bay
# Processing Record 9 of Set 15 | sibiti
# Processing Record 10 of Set 15 | chagda
# City not found. Skipping...
# Processing Record 11 of Set 15 | bombay
# Processing Record 12 of Set 15 | turukhansk
# Processing Record 13 of Set 15 | shar
# Processing Record 14 of Set 15 | san policarpo
# Processing Record 15 of Set 15 | leh
# Processing Record 16 of Set 15 | sawakin
# Processing Record 17 of Set 15 | tranas
# Processing Record 18 of Set 15 | aksu
# Processing Record 19 of Set 15 | zaysan
# Processing Record 20 of Set 15 | langsa
# Processing Record 21 of Set 15 | sosnovskiy
# City not found. Skipping...
# Processing Record 22 of Set 15 | karakulino
# Processing Record 23 of Set 15 | rumonge
# Processing Record 24 of Set 15 | severo-yeniseyskiy
# Processing Record 25 of Set 15 | mponela
# Processing Record 26 of Set 15 | ballina
# Processing Record 27 of Set 15 | muroto
# Processing Record 28 of Set 15 | gisborne
# Processing Record 29 of Set 15 | harnosand
# Processing Record 30 of Set 15 | tilichiki
# Processing Record 31 of Set 15 | takoradi
# Processing Record 32 of Set 15 | bilibino
# Processing Record 33 of Set 15 | vila
# Processing Record 34 of Set 15 | jalingo
# Processing Record 35 of Set 15 | berdigestyakh
# Processing Record 36 of Set 15 | popova
# Processing Record 37 of Set 15 | masallatah
# Processing Record 38 of Set 15 | sehithwa
# Processing Record 39 of Set 15 | solsvik
# City not found. Skipping...
# Processing Record 40 of Set 15 | bokhan
# Processing Record 41 of Set 15 | mercedes
# Processing Record 42 of Set 15 | balarampur
# Processing Record 43 of Set 15 | vawkavysk
# Processing Record 44 of Set 15 | lensk
# Processing Record 45 of Set 15 | tommot
# Processing Record 46 of Set 15 | bindura
# Processing Record 47 of Set 15 | tasbuget
# City not found. Skipping...
# Processing Record 48 of Set 15 | abiy adi
# City not found. Skipping...
# Processing Record 49 of Set 15 | mayumba
# Processing Record 50 of Set 15 | manggar
# Processing Record 1 of Set 16 | tazmalt
# Processing Record 2 of Set 16 | mackay
# Processing Record 3 of Set 16 | awbari
# Processing Record 4 of Set 16 | sibay
# Processing Record 5 of Set 16 | neryungri
# Processing Record 6 of Set 16 | pareora
# Processing Record 7 of Set 16 | keffi
# Processing Record 8 of Set 16 | wattegama
# Processing Record 9 of Set 16 | manzhouli
# Processing Record 10 of Set 16 | dohar
# Processing Record 11 of Set 16 | byron bay
# Processing Record 12 of Set 16 | tessalit
# Processing Record 13 of Set 16 | biu
# Processing Record 14 of Set 16 | henties bay
# Processing Record 15 of Set 16 | westport
# Processing Record 16 of Set 16 | veraval
# Processing Record 17 of Set 16 | muncar
# Processing Record 18 of Set 16 | vologda
# Processing Record 19 of Set 16 | suntar
# Processing Record 20 of Set 16 | vredendal
# Processing Record 21 of Set 16 | changping
# Processing Record 22 of Set 16 | tottori
# Processing Record 23 of Set 16 | phangnga
# Processing Record 24 of Set 16 | kandrian
# Processing Record 25 of Set 16 | umm kaddadah
# Processing Record 26 of Set 16 | magaria
# Processing Record 27 of Set 16 | asahikawa
# Processing Record 28 of Set 16 | karlskoga
# Processing Record 29 of Set 16 | marseille
# Processing Record 30 of Set 16 | soyo
# Processing Record 31 of Set 16 | malwan
# City not found. Skipping...
# Processing Record 32 of Set 16 | lokken verk
# City not found. Skipping...
# Processing Record 33 of Set 16 | kirillov
# Processing Record 34 of Set 16 | amahai
# Processing Record 35 of Set 16 | bo rai
# Processing Record 36 of Set 16 | biak
# Processing Record 37 of Set 16 | moranbah
# Processing Record 38 of Set 16 | abu samrah
# Processing Record 39 of Set 16 | sterlibashevo
# Processing Record 40 of Set 16 | salym
# Processing Record 41 of Set 16 | tungkang
# City not found. Skipping...
# Processing Record 42 of Set 16 | petropavlovsk-kamchatskiy
# Processing Record 43 of Set 16 | tomohon
# Processing Record 44 of Set 16 | daltenganj
# Processing Record 45 of Set 16 | kasongo-lunda
# Processing Record 46 of Set 16 | hit
# Processing Record 47 of Set 16 | shaoguan
# Processing Record 48 of Set 16 | otradnoye
# Processing Record 49 of Set 16 | sayanskiy
# City not found. Skipping...
# Processing Record 50 of Set 16 | emmen
# Processing Record 1 of Set 17 | raga
# Processing Record 2 of Set 17 | kortkeros
# Processing Record 3 of Set 17 | taicheng
# Processing Record 4 of Set 17 | sunbury
# Processing Record 5 of Set 17 | san jose
# Processing Record 6 of Set 17 | walvis bay
# Processing Record 7 of Set 17 | romny
# Processing Record 8 of Set 17 | svetlyy
# Processing Record 9 of Set 17 | gewane
# Processing Record 10 of Set 17 | wulanhaote
# City not found. Skipping...
# Processing Record 11 of Set 17 | atasu
# Processing Record 12 of Set 17 | derzhavinsk
# Processing Record 13 of Set 17 | batticaloa
# Processing Record 14 of Set 17 | sedelnikovo
# City not found. Skipping...
# Processing Record 15 of Set 17 | halvad
# Processing Record 16 of Set 17 | totma
# Processing Record 17 of Set 17 | gawler
# Processing Record 18 of Set 17 | enkoping
# Processing Record 19 of Set 17 | victor harbor
# Processing Record 20 of Set 17 | argayash
# Processing Record 21 of Set 17 | methoni
# Processing Record 22 of Set 17 | oksfjord
# Processing Record 23 of Set 17 | udachnyy
# Processing Record 24 of Set 17 | port macquarie
# Processing Record 25 of Set 17 | karachi
# Processing Record 26 of Set 17 | farafangana
# Processing Record 27 of Set 17 | wajima
# Processing Record 28 of Set 17 | khani
# Processing Record 29 of Set 17 | geylegphug
# City not found. Skipping...
# Processing Record 30 of Set 17 | kiruna
# Processing Record 31 of Set 17 | thohoyandou
# Processing Record 32 of Set 17 | kaihua
# Processing Record 33 of Set 17 | keti bandar
# Processing Record 34 of Set 17 | phan rang
# City not found. Skipping...
# Processing Record 35 of Set 17 | karymskoye
# Processing Record 36 of Set 17 | ust-nera
# Processing Record 37 of Set 17 | kirovskiy
# Processing Record 38 of Set 17 | chingirlau
# Processing Record 39 of Set 17 | mecca
# Processing Record 40 of Set 17 | kondinskoye
# Processing Record 41 of Set 17 | chulym
# Processing Record 42 of Set 17 | masunga
# Processing Record 43 of Set 17 | mont-de-marsan
# Processing Record 44 of Set 17 | nazarovo
# Processing Record 45 of Set 17 | minab
# Processing Record 46 of Set 17 | dalbandin
# Processing Record 47 of Set 17 | yuli
# Processing Record 48 of Set 17 | sampit
# Processing Record 49 of Set 17 | solnechnyy
# Processing Record 50 of Set 17 | balud
# Processing Record 1 of Set 18 | wajir
# Processing Record 2 of Set 18 | rochegda
# Processing Record 3 of Set 18 | tuggurt
# City not found. Skipping...
# Processing Record 4 of Set 18 | ligayan
# Processing Record 5 of Set 18 | verkhovazhye
# Processing Record 6 of Set 18 | tanout
# Processing Record 7 of Set 18 | warmbad
# Processing Record 8 of Set 18 | nizhniy ingash
# Processing Record 9 of Set 18 | takaka
# Processing Record 10 of Set 18 | sardarshahr
# Processing Record 11 of Set 18 | bud
# Processing Record 12 of Set 18 | filingue
# Processing Record 13 of Set 18 | tuy hoa
# Processing Record 14 of Set 18 | kalnciems
# Processing Record 15 of Set 18 | barbar
# City not found. Skipping...
# Processing Record 16 of Set 18 | krasnoselkup
# Processing Record 17 of Set 18 | ndele
# Processing Record 18 of Set 18 | ekhabi
# Processing Record 19 of Set 18 | kegayli
# City not found. Skipping...
# Processing Record 20 of Set 18 | kungurtug
# Processing Record 21 of Set 18 | amazar
# Processing Record 22 of Set 18 | yirol
# City not found. Skipping...
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#              City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0        Sobolevo  54.4299   31.8996     66.22        73         100
# 1       Ostrovnoy  68.0531   39.5131     49.12        83          15
# 2           Alihe  50.5667  123.7167     47.48        97           8
# 3        Kargasok  59.0556   80.8572     51.71        87          24
# 4    Richards Bay -28.7830   32.0377     63.81        76           4
# 5            Kaeo -35.1000  173.7833     49.32        92          20
# 6  Saint-Philippe -21.3585   55.7679     69.35        75          43
# 7         Kamenka  51.3223   42.7678     76.77        56          67
# 8            Tura  25.5198   90.2201     73.60        98          87
# 9          Dikson  73.5069   80.5464     39.36        98          97
#
#    Wind Speed Country        Conditions
# 0        0.31      RU   overcast clouds
# 1        8.61      RU        few clouds
# 2        2.48      CN         clear sky
# 3        5.44      RU        few clouds
# 4        4.00      ZA         clear sky
# 5        5.10      NZ        few clouds
# 6       11.83      RE  scattered clouds
# 7        4.45      RU     broken clouds
# 8        3.44      IN   overcast clouds
# 9        4.52      RU   overcast clouds

# %%
# Create the output file (CSV).
output_data_file = "weather_data/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
